# %%
from GraphViewer import GraphViewer

# %%
graph = {1: [2, 3], 3: [4, 5], 4: 3}

# %%
gv = GraphViewer()
gv.view(graph)

# %%
gv.graph

# %%
gv.view(graph, is_directed_graph=False)

# %%
gv.graph
